# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import f1_score, classification_report
from sklearn.metrics import confusion_matrix
import random
import torch
import torch.nn as nn
import hashlib
from tqdm import tqdm

# %%
random.seed(1234)
np.random.seed(1234)
torch.manual_seed(1234)

# %%
import tarfile
import requests

FOLDER = "datasets/"
PATH = "sentences.tar.bz2"
URL = "https://downloads.tatoeba.org/exports/" + PATH

def download_dataset():
    req = requests.get(URL, stream=True)

    if req.status_code != 200:
        print("Failed to download file, got status: " + req.status_code)
        req.close()
    else:
        with open(FOLDER + PATH, "wb") as fd:
            bytes = 0
            for chunk in req.iter_content(chunk_size=65536):
                fd.write(chunk)
                bytes += len(chunk)
                print(f"Downloading: {bytes} bytes written to {PATH}")
        print(f"{PATH} downloaded.")
        req.close()

def extract_dataset():
    with tarfile.open(FOLDER + PATH, "r:bz2") as tar:
        tar.extractall(FOLDER)
        print(f"{PATH} extracted to '{FOLDER}'.")

# %%
#download_dataset()
#extract_dataset()
# Out:
# Downloading: 65536 bytes written to sentences.tar.bz2
# Downloading: 131072 bytes written to sentences.tar.bz2
# Downloading: 196608 bytes written to sentences.tar.bz2
# Downloading: 262144 bytes written to sentences.tar.bz2
# Downloading: 327680 bytes written to sentences.tar.bz2
# Downloading: 393216 bytes written to sentences.tar.bz2
# Downloading: 458752 bytes written to sentences.tar.bz2
# Downloading: 524288 bytes written to sentences.tar.bz2
# Downloading: 589824 bytes written to sentences.tar.bz2
# Downloading: 655360 bytes written to sentences.tar.bz2
# Downloading: 720896 bytes written to sentences.tar.bz2
# Downloading: 786432 bytes written to sentences.tar.bz2
# Downloading: 851968 bytes written to sentences.tar.bz2
# Downloading: 917504 bytes written to sentences.tar.bz2
# Downloading: 983040 bytes written to sentences.tar.bz2
# Downloading: 1048576 bytes written to sentences.tar.bz2
# Downloading: 1114112 bytes written to sentences.tar.bz2
# Downloading: 1179648 bytes written to sentences.tar.bz2
# Downloading: 1245184 bytes written to sentences.tar.bz2
# Downloading: 1310720 bytes written to sentences.tar.bz2
# Downloading: 1376256 bytes written to sentences.tar.bz2
# Downloading: 1441792 bytes written to sentences.tar.bz2
# Downloading: 1507328 bytes written to sentences.tar.bz2
# Downloading: 1572864 bytes written to sentences.tar.bz2
# Downloading: 1638400 bytes written to sentences.tar.bz2
# Downloading: 1703936 bytes written to sentences.tar.bz2
# Downloading: 1769472 bytes written to sentences.tar.bz2
# Downloading: 1835008 bytes written to sentences.tar.bz2
# Downloading: 1900544 bytes written to sentences.tar.bz2
# Downloading: 1966080 bytes written to sentences.tar.bz2
# Downloading: 2031616 bytes written to sentences.tar.bz2
# Downloading: 2097152 bytes written to sentences.tar.bz2
# Downloading: 2162688 bytes written to sentences.tar.bz2
# Downloading: 2228224 bytes written to sentences.tar.bz2
# Downloading: 2293760 bytes written to sentences.tar.bz2
# Downloading: 2359296 bytes written to sentences.tar.bz2
# Downloading: 2424832 bytes written to sentences.tar.bz2
# Downloading: 2490368 bytes written to sentences.tar.bz2
# Downloading: 2555904 bytes written to sentences.tar.bz2
# Downloading: 2621440 bytes written to sentences.tar.bz2
# Downloading: 2686976 bytes written to sentences.tar.bz2
# Downloading: 2752512 bytes written to sentences.tar.bz2
# Downloading: 2818048 bytes written to sentences.tar.bz2
# Downloading: 2883584 bytes written to sentences.tar.bz2
# Downloading: 2949120 bytes written to sentences.tar.bz2
# Downloading: 3014656 bytes written to sentences.tar.bz2
# Downloading: 3080192 bytes written to sentences.tar.bz2
# Downloading: 3145728 bytes written to sentences.tar.bz2
# Downloading: 3211264 bytes written to sentences.tar.bz2
# Downloading: 3276800 bytes written to sentences.tar.bz2
# Downloading: 3342336 bytes written to sentences.tar.bz2
# Downloading: 3407872 bytes written to sentences.tar.bz2
# Downloading: 3473408 bytes written to sentences.tar.bz2
# Downloading: 3538944 bytes written to sentences.tar.bz2
# Downloading: 3604480 bytes written to sentences.tar.bz2
# Downloading: 3670016 bytes written to sentences.tar.bz2
# Downloading: 3735552 bytes written to sentences.tar.bz2
# Downloading: 3801088 bytes written to sentences.tar.bz2
# Downloading: 3866624 bytes written to sentences.tar.bz2
# Downloading: 3932160 bytes written to sentences.tar.bz2
# Downloading: 3997696 bytes written to sentences.tar.bz2
# Downloading: 4063232 bytes written to sentences.tar.bz2
# Downloading: 4128768 bytes written to sentences.tar.bz2
# Downloading: 4194304 bytes written to sentences.tar.bz2
# Downloading: 4259840 bytes written to sentences.tar.bz2
# Downloading: 4325376 bytes written to sentences.tar.bz2
# Downloading: 4390912 bytes written to sentences.tar.bz2
# Downloading: 4456448 bytes written to sentences.tar.bz2
# Downloading: 4521984 bytes written to sentences.tar.bz2
# Downloading: 4587520 bytes written to sentences.tar.bz2
# Downloading: 4653056 bytes written to sentences.tar.bz2
# Downloading: 4718592 bytes written to sentences.tar.bz2
# Downloading: 4784128 bytes written to sentences.tar.bz2
# Downloading: 4849664 bytes written to sentences.tar.bz2
# Downloading: 4915200 bytes written to sentences.tar.bz2
# Downloading: 4980736 bytes written to sentences.tar.bz2
# Downloading: 5046272 bytes written to sentences.tar.bz2
# Downloading: 5111808 bytes written to sentences.tar.bz2
# Downloading: 5177344 bytes written to sentences.tar.bz2
# Downloading: 5242880 bytes written to sentences.tar.bz2
# Downloading: 5308416 bytes written to sentences.tar.bz2
# Downloading: 5373952 bytes written to sentences.tar.bz2
# Downloading: 5439488 bytes written to sentences.tar.bz2
# Downloading: 5505024 bytes written to sentences.tar.bz2
# Downloading: 5570560 bytes written to sentences.tar.bz2
# Downloading: 5636096 bytes written to sentences.tar.bz2
# Downloading: 5701632 bytes written to sentences.tar.bz2
# Downloading: 5767168 bytes written to sentences.tar.bz2
# Downloading: 5832704 bytes written to sentences.tar.bz2
# Downloading: 5898240 bytes written to sentences.tar.bz2
# Downloading: 5963776 bytes written to sentences.tar.bz2
# Downloading: 6029312 bytes written to sentences.tar.bz2
# Downloading: 6094848 bytes written to sentences.tar.bz2
# Downloading: 6160384 bytes written to sentences.tar.bz2
# Downloading: 6225920 bytes written to sentences.tar.bz2
# Downloading: 6291456 bytes written to sentences.tar.bz2
# Downloading: 6356992 bytes written to sentences.tar.bz2
# Downloading: 6422528 bytes written to sentences.tar.bz2
# Downloading: 6488064 bytes written to sentences.tar.bz2
# Downloading: 6553600 bytes written to sentences.tar.bz2
# Downloading: 6619136 bytes written to sentences.tar.bz2
# Downloading: 6684672 bytes written to sentences.tar.bz2
# Downloading: 6750208 bytes written to sentences.tar.bz2
# Downloading: 6815744 bytes written to sentences.tar.bz2
# Downloading: 6881280 bytes written to sentences.tar.bz2
# Downloading: 6946816 bytes written to sentences.tar.bz2
# Downloading: 7012352 bytes written to sentences.tar.bz2
# Downloading: 7077888 bytes written to sentences.tar.bz2
# Downloading: 7143424 bytes written to sentences.tar.bz2
# Downloading: 7208960 bytes written to sentences.tar.bz2
# Downloading: 7274496 bytes written to sentences.tar.bz2
# Downloading: 7340032 bytes written to sentences.tar.bz2
# Downloading: 7405568 bytes written to sentences.tar.bz2
# Downloading: 7471104 bytes written to sentences.tar.bz2
# Downloading: 7536640 bytes written to sentences.tar.bz2
# Downloading: 7602176 bytes written to sentences.tar.bz2
# Downloading: 7667712 bytes written to sentences.tar.bz2
# Downloading: 7733248 bytes written to sentences.tar.bz2
# Downloading: 7798784 bytes written to sentences.tar.bz2
# Downloading: 7864320 bytes written to sentences.tar.bz2
# Downloading: 7929856 bytes written to sentences.tar.bz2
# Downloading: 7995392 bytes written to sentences.tar.bz2
# Downloading: 8060928 bytes written to sentences.tar.bz2
# Downloading: 8126464 bytes written to sentences.tar.bz2
# Downloading: 8192000 bytes written to sentences.tar.bz2
# Downloading: 8257536 bytes written to sentences.tar.bz2
# Downloading: 8323072 bytes written to sentences.tar.bz2
# Downloading: 8388608 bytes written to sentences.tar.bz2
# Downloading: 8454144 bytes written to sentences.tar.bz2
# Downloading: 8519680 bytes written to sentences.tar.bz2
# Downloading: 8585216 bytes written to sentences.tar.bz2
# Downloading: 8650752 bytes written to sentences.tar.bz2
# Downloading: 8716288 bytes written to sentences.tar.bz2
# Downloading: 8781824 bytes written to sentences.tar.bz2
# Downloading: 8847360 bytes written to sentences.tar.bz2
# Downloading: 8912896 bytes written to sentences.tar.bz2
# Downloading: 8978432 bytes written to sentences.tar.bz2
# Downloading: 9043968 bytes written to sentences.tar.bz2
# Downloading: 9109504 bytes written to sentences.tar.bz2
# Downloading: 9175040 bytes written to sentences.tar.bz2
# Downloading: 9240576 bytes written to sentences.tar.bz2
# Downloading: 9306112 bytes written to sentences.tar.bz2
# Downloading: 9371648 bytes written to sentences.tar.bz2
# Downloading: 9437184 bytes written to sentences.tar.bz2
# Downloading: 9502720 bytes written to sentences.tar.bz2
# Downloading: 9568256 bytes written to sentences.tar.bz2
# Downloading: 9633792 bytes written to sentences.tar.bz2
# Downloading: 9699328 bytes written to sentences.tar.bz2
# Downloading: 9764864 bytes written to sentences.tar.bz2
# Downloading: 9830400 bytes written to sentences.tar.bz2
# Downloading: 9895936 bytes written to sentences.tar.bz2
# Downloading: 9961472 bytes written to sentences.tar.bz2
# Downloading: 10027008 bytes written to sentences.tar.bz2
# Downloading: 10092544 bytes written to sentences.tar.bz2
# Downloading: 10158080 bytes written to sentences.tar.bz2
# Downloading: 10223616 bytes written to sentences.tar.bz2
# Downloading: 10289152 bytes written to sentences.tar.bz2
# Downloading: 10354688 bytes written to sentences.tar.bz2
# Downloading: 10420224 bytes written to sentences.tar.bz2
# Downloading: 10485760 bytes written to sentences.tar.bz2
# Downloading: 10551296 bytes written to sentences.tar.bz2
# Downloading: 10616832 bytes written to sentences.tar.bz2
# Downloading: 10682368 bytes written to sentences.tar.bz2
# Downloading: 10747904 bytes written to sentences.tar.bz2
# Downloading: 10813440 bytes written to sentences.tar.bz2
# Downloading: 10878976 bytes written to sentences.tar.bz2
# Downloading: 10944512 bytes written to sentences.tar.bz2
# Downloading: 11010048 bytes written to sentences.tar.bz2
# Downloading: 11075584 bytes written to sentences.tar.bz2
# Downloading: 11141120 bytes written to sentences.tar.bz2
# Downloading: 11206656 bytes written to sentences.tar.bz2
# Downloading: 11272192 bytes written to sentences.tar.bz2
# Downloading: 11337728 bytes written to sentences.tar.bz2
# Downloading: 11403264 bytes written to sentences.tar.bz2
# Downloading: 11468800 bytes written to sentences.tar.bz2
# Downloading: 11534336 bytes written to sentences.tar.bz2
# Downloading: 11599872 bytes written to sentences.tar.bz2
# Downloading: 11665408 bytes written to sentences.tar.bz2
# Downloading: 11730944 bytes written to sentences.tar.bz2
# Downloading: 11796480 bytes written to sentences.tar.bz2
# Downloading: 11862016 bytes written to sentences.tar.bz2
# Downloading: 11927552 bytes written to sentences.tar.bz2
# Downloading: 11993088 bytes written to sentences.tar.bz2
# Downloading: 12058624 bytes written to sentences.tar.bz2
# Downloading: 12124160 bytes written to sentences.tar.bz2
# Downloading: 12189696 bytes written to sentences.tar.bz2
# Downloading: 12255232 bytes written to sentences.tar.bz2
# Downloading: 12320768 bytes written to sentences.tar.bz2
# Downloading: 12386304 bytes written to sentences.tar.bz2
# Downloading: 12451840 bytes written to sentences.tar.bz2
# Downloading: 12517376 bytes written to sentences.tar.bz2
# Downloading: 12582912 bytes written to sentences.tar.bz2
# Downloading: 12648448 bytes written to sentences.tar.bz2
# Downloading: 12713984 bytes written to sentences.tar.bz2
# Downloading: 12779520 bytes written to sentences.tar.bz2
# Downloading: 12845056 bytes written to sentences.tar.bz2
# Downloading: 12910592 bytes written to sentences.tar.bz2
# Downloading: 12976128 bytes written to sentences.tar.bz2
# Downloading: 13041664 bytes written to sentences.tar.bz2
# Downloading: 13107200 bytes written to sentences.tar.bz2
# Downloading: 13172736 bytes written to sentences.tar.bz2
# Downloading: 13238272 bytes written to sentences.tar.bz2
# Downloading: 13303808 bytes written to sentences.tar.bz2
# Downloading: 13369344 bytes written to sentences.tar.bz2
# Downloading: 13434880 bytes written to sentences.tar.bz2
# Downloading: 13500416 bytes written to sentences.tar.bz2
# Downloading: 13565952 bytes written to sentences.tar.bz2
# Downloading: 13631488 bytes written to sentences.tar.bz2
# Downloading: 13697024 bytes written to sentences.tar.bz2
# Downloading: 13762560 bytes written to sentences.tar.bz2
# Downloading: 13828096 bytes written to sentences.tar.bz2
# Downloading: 13893632 bytes written to sentences.tar.bz2
# Downloading: 13959168 bytes written to sentences.tar.bz2
# Downloading: 14024704 bytes written to sentences.tar.bz2
# Downloading: 14090240 bytes written to sentences.tar.bz2
# Downloading: 14155776 bytes written to sentences.tar.bz2
# Downloading: 14221312 bytes written to sentences.tar.bz2
# Downloading: 14286848 bytes written to sentences.tar.bz2
# Downloading: 14352384 bytes written to sentences.tar.bz2
# Downloading: 14417920 bytes written to sentences.tar.bz2
# Downloading: 14483456 bytes written to sentences.tar.bz2
# Downloading: 14548992 bytes written to sentences.tar.bz2
# Downloading: 14614528 bytes written to sentences.tar.bz2
# Downloading: 14680064 bytes written to sentences.tar.bz2
# Downloading: 14745600 bytes written to sentences.tar.bz2
# Downloading: 14811136 bytes written to sentences.tar.bz2
# Downloading: 14876672 bytes written to sentences.tar.bz2
# Downloading: 14942208 bytes written to sentences.tar.bz2
# Downloading: 15007744 bytes written to sentences.tar.bz2
# Downloading: 15073280 bytes written to sentences.tar.bz2
# Downloading: 15138816 bytes written to sentences.tar.bz2
# Downloading: 15204352 bytes written to sentences.tar.bz2
# Downloading: 15269888 bytes written to sentences.tar.bz2
# Downloading: 15335424 bytes written to sentences.tar.bz2
# Downloading: 15400960 bytes written to sentences.tar.bz2
# Downloading: 15466496 bytes written to sentences.tar.bz2
# Downloading: 15532032 bytes written to sentences.tar.bz2
# Downloading: 15597568 bytes written to sentences.tar.bz2
# Downloading: 15663104 bytes written to sentences.tar.bz2
# Downloading: 15728640 bytes written to sentences.tar.bz2
# Downloading: 15794176 bytes written to sentences.tar.bz2
# Downloading: 15859712 bytes written to sentences.tar.bz2
# Downloading: 15925248 bytes written to sentences.tar.bz2
# Downloading: 15990784 bytes written to sentences.tar.bz2
# Downloading: 16056320 bytes written to sentences.tar.bz2
# Downloading: 16121856 bytes written to sentences.tar.bz2
# Downloading: 16187392 bytes written to sentences.tar.bz2
# Downloading: 16252928 bytes written to sentences.tar.bz2
# Downloading: 16318464 bytes written to sentences.tar.bz2
# Downloading: 16384000 bytes written to sentences.tar.bz2
# Downloading: 16449536 bytes written to sentences.tar.bz2
# Downloading: 16515072 bytes written to sentences.tar.bz2
# Downloading: 16580608 bytes written to sentences.tar.bz2
# Downloading: 16646144 bytes written to sentences.tar.bz2
# Downloading: 16711680 bytes written to sentences.tar.bz2
# Downloading: 16777216 bytes written to sentences.tar.bz2
# Downloading: 16842752 bytes written to sentences.tar.bz2
# Downloading: 16908288 bytes written to sentences.tar.bz2
# Downloading: 16973824 bytes written to sentences.tar.bz2
# Downloading: 17039360 bytes written to sentences.tar.bz2
# Downloading: 17104896 bytes written to sentences.tar.bz2
# Downloading: 17170432 bytes written to sentences.tar.bz2
# Downloading: 17235968 bytes written to sentences.tar.bz2
# Downloading: 17301504 bytes written to sentences.tar.bz2
# Downloading: 17367040 bytes written to sentences.tar.bz2
# Downloading: 17432576 bytes written to sentences.tar.bz2
# Downloading: 17498112 bytes written to sentences.tar.bz2
# Downloading: 17563648 bytes written to sentences.tar.bz2
# Downloading: 17629184 bytes written to sentences.tar.bz2
# Downloading: 17694720 bytes written to sentences.tar.bz2
# Downloading: 17760256 bytes written to sentences.tar.bz2
# Downloading: 17825792 bytes written to sentences.tar.bz2
# Downloading: 17891328 bytes written to sentences.tar.bz2
# Downloading: 17956864 bytes written to sentences.tar.bz2
# Downloading: 18022400 bytes written to sentences.tar.bz2
# Downloading: 18087936 bytes written to sentences.tar.bz2
# Downloading: 18153472 bytes written to sentences.tar.bz2
# Downloading: 18219008 bytes written to sentences.tar.bz2
# Downloading: 18284544 bytes written to sentences.tar.bz2
# Downloading: 18350080 bytes written to sentences.tar.bz2
# Downloading: 18415616 bytes written to sentences.tar.bz2
# Downloading: 18481152 bytes written to sentences.tar.bz2
# Downloading: 18546688 bytes written to sentences.tar.bz2
# Downloading: 18612224 bytes written to sentences.tar.bz2
# Downloading: 18677760 bytes written to sentences.tar.bz2
# Downloading: 18743296 bytes written to sentences.tar.bz2
# Downloading: 18808832 bytes written to sentences.tar.bz2
# Downloading: 18874368 bytes written to sentences.tar.bz2
# Downloading: 18939904 bytes written to sentences.tar.bz2
# Downloading: 19005440 bytes written to sentences.tar.bz2
# Downloading: 19070976 bytes written to sentences.tar.bz2
# Downloading: 19136512 bytes written to sentences.tar.bz2
# Downloading: 19202048 bytes written to sentences.tar.bz2
# Downloading: 19267584 bytes written to sentences.tar.bz2
# Downloading: 19333120 bytes written to sentences.tar.bz2
# Downloading: 19398656 bytes written to sentences.tar.bz2
# Downloading: 19464192 bytes written to sentences.tar.bz2
# Downloading: 19529728 bytes written to sentences.tar.bz2
# Downloading: 19595264 bytes written to sentences.tar.bz2
# Downloading: 19660800 bytes written to sentences.tar.bz2
# Downloading: 19726336 bytes written to sentences.tar.bz2
# Downloading: 19791872 bytes written to sentences.tar.bz2
# Downloading: 19857408 bytes written to sentences.tar.bz2
# Downloading: 19922944 bytes written to sentences.tar.bz2
# Downloading: 19988480 bytes written to sentences.tar.bz2
# Downloading: 20054016 bytes written to sentences.tar.bz2
# Downloading: 20119552 bytes written to sentences.tar.bz2
# Downloading: 20185088 bytes written to sentences.tar.bz2
# Downloading: 20250624 bytes written to sentences.tar.bz2
# Downloading: 20316160 bytes written to sentences.tar.bz2
# Downloading: 20381696 bytes written to sentences.tar.bz2
# Downloading: 20447232 bytes written to sentences.tar.bz2
# Downloading: 20512768 bytes written to sentences.tar.bz2
# Downloading: 20578304 bytes written to sentences.tar.bz2
# Downloading: 20643840 bytes written to sentences.tar.bz2
# Downloading: 20709376 bytes written to sentences.tar.bz2
# Downloading: 20774912 bytes written to sentences.tar.bz2
# Downloading: 20840448 bytes written to sentences.tar.bz2
# Downloading: 20905984 bytes written to sentences.tar.bz2
# Downloading: 20971520 bytes written to sentences.tar.bz2
# Downloading: 21037056 bytes written to sentences.tar.bz2
# Downloading: 21102592 bytes written to sentences.tar.bz2
# Downloading: 21168128 bytes written to sentences.tar.bz2
# Downloading: 21233664 bytes written to sentences.tar.bz2
# Downloading: 21299200 bytes written to sentences.tar.bz2
# Downloading: 21364736 bytes written to sentences.tar.bz2
# Downloading: 21430272 bytes written to sentences.tar.bz2
# Downloading: 21495808 bytes written to sentences.tar.bz2
# Downloading: 21561344 bytes written to sentences.tar.bz2
# Downloading: 21626880 bytes written to sentences.tar.bz2
# Downloading: 21692416 bytes written to sentences.tar.bz2
# Downloading: 21757952 bytes written to sentences.tar.bz2
# Downloading: 21823488 bytes written to sentences.tar.bz2
# Downloading: 21889024 bytes written to sentences.tar.bz2
# Downloading: 21954560 bytes written to sentences.tar.bz2
# Downloading: 22020096 bytes written to sentences.tar.bz2
# Downloading: 22085632 bytes written to sentences.tar.bz2
# Downloading: 22151168 bytes written to sentences.tar.bz2
# Downloading: 22216704 bytes written to sentences.tar.bz2
# Downloading: 22282240 bytes written to sentences.tar.bz2
# Downloading: 22347776 bytes written to sentences.tar.bz2
# Downloading: 22413312 bytes written to sentences.tar.bz2
# Downloading: 22478848 bytes written to sentences.tar.bz2
# Downloading: 22544384 bytes written to sentences.tar.bz2
# Downloading: 22609920 bytes written to sentences.tar.bz2
# Downloading: 22675456 bytes written to sentences.tar.bz2
# Downloading: 22740992 bytes written to sentences.tar.bz2
# Downloading: 22806528 bytes written to sentences.tar.bz2
# Downloading: 22872064 bytes written to sentences.tar.bz2
# Downloading: 22937600 bytes written to sentences.tar.bz2
# Downloading: 23003136 bytes written to sentences.tar.bz2
# Downloading: 23068672 bytes written to sentences.tar.bz2
# Downloading: 23134208 bytes written to sentences.tar.bz2
# Downloading: 23199744 bytes written to sentences.tar.bz2
# Downloading: 23265280 bytes written to sentences.tar.bz2
# Downloading: 23330816 bytes written to sentences.tar.bz2
# Downloading: 23396352 bytes written to sentences.tar.bz2
# Downloading: 23461888 bytes written to sentences.tar.bz2
# Downloading: 23527424 bytes written to sentences.tar.bz2
# Downloading: 23592960 bytes written to sentences.tar.bz2
# Downloading: 23658496 bytes written to sentences.tar.bz2
# Downloading: 23724032 bytes written to sentences.tar.bz2
# Downloading: 23789568 bytes written to sentences.tar.bz2
# Downloading: 23855104 bytes written to sentences.tar.bz2
# Downloading: 23920640 bytes written to sentences.tar.bz2
# Downloading: 23986176 bytes written to sentences.tar.bz2
# Downloading: 24051712 bytes written to sentences.tar.bz2
# Downloading: 24117248 bytes written to sentences.tar.bz2
# Downloading: 24182784 bytes written to sentences.tar.bz2
# Downloading: 24248320 bytes written to sentences.tar.bz2
# Downloading: 24313856 bytes written to sentences.tar.bz2
# Downloading: 24379392 bytes written to sentences.tar.bz2
# Downloading: 24444928 bytes written to sentences.tar.bz2
# Downloading: 24510464 bytes written to sentences.tar.bz2
# Downloading: 24576000 bytes written to sentences.tar.bz2
# Downloading: 24641536 bytes written to sentences.tar.bz2
# Downloading: 24707072 bytes written to sentences.tar.bz2
# Downloading: 24772608 bytes written to sentences.tar.bz2
# Downloading: 24838144 bytes written to sentences.tar.bz2
# Downloading: 24903680 bytes written to sentences.tar.bz2
# Downloading: 24969216 bytes written to sentences.tar.bz2
# Downloading: 25034752 bytes written to sentences.tar.bz2
# Downloading: 25100288 bytes written to sentences.tar.bz2
# Downloading: 25165824 bytes written to sentences.tar.bz2
# Downloading: 25231360 bytes written to sentences.tar.bz2
# Downloading: 25296896 bytes written to sentences.tar.bz2
# Downloading: 25362432 bytes written to sentences.tar.bz2
# Downloading: 25427968 bytes written to sentences.tar.bz2
# Downloading: 25493504 bytes written to sentences.tar.bz2
# Downloading: 25559040 bytes written to sentences.tar.bz2
# Downloading: 25624576 bytes written to sentences.tar.bz2
# Downloading: 25690112 bytes written to sentences.tar.bz2
# Downloading: 25755648 bytes written to sentences.tar.bz2
# Downloading: 25821184 bytes written to sentences.tar.bz2
# Downloading: 25886720 bytes written to sentences.tar.bz2
# Downloading: 25952256 bytes written to sentences.tar.bz2
# Downloading: 26017792 bytes written to sentences.tar.bz2
# Downloading: 26083328 bytes written to sentences.tar.bz2
# Downloading: 26148864 bytes written to sentences.tar.bz2
# Downloading: 26214400 bytes written to sentences.tar.bz2
# Downloading: 26279936 bytes written to sentences.tar.bz2
# Downloading: 26345472 bytes written to sentences.tar.bz2
# Downloading: 26411008 bytes written to sentences.tar.bz2
# Downloading: 26476544 bytes written to sentences.tar.bz2
# Downloading: 26542080 bytes written to sentences.tar.bz2
# Downloading: 26607616 bytes written to sentences.tar.bz2
# Downloading: 26673152 bytes written to sentences.tar.bz2
# Downloading: 26738688 bytes written to sentences.tar.bz2
# Downloading: 26804224 bytes written to sentences.tar.bz2
# Downloading: 26869760 bytes written to sentences.tar.bz2
# Downloading: 26935296 bytes written to sentences.tar.bz2
# Downloading: 27000832 bytes written to sentences.tar.bz2
# Downloading: 27066368 bytes written to sentences.tar.bz2
# Downloading: 27131904 bytes written to sentences.tar.bz2
# Downloading: 27197440 bytes written to sentences.tar.bz2
# Downloading: 27262976 bytes written to sentences.tar.bz2
# Downloading: 27328512 bytes written to sentences.tar.bz2
# Downloading: 27394048 bytes written to sentences.tar.bz2
# Downloading: 27459584 bytes written to sentences.tar.bz2
# Downloading: 27525120 bytes written to sentences.tar.bz2
# Downloading: 27590656 bytes written to sentences.tar.bz2
# Downloading: 27656192 bytes written to sentences.tar.bz2
# Downloading: 27721728 bytes written to sentences.tar.bz2
# Downloading: 27787264 bytes written to sentences.tar.bz2
# Downloading: 27852800 bytes written to sentences.tar.bz2
# Downloading: 27918336 bytes written to sentences.tar.bz2
# Downloading: 27983872 bytes written to sentences.tar.bz2
# Downloading: 28049408 bytes written to sentences.tar.bz2
# Downloading: 28114944 bytes written to sentences.tar.bz2
# Downloading: 28180480 bytes written to sentences.tar.bz2
# Downloading: 28246016 bytes written to sentences.tar.bz2
# Downloading: 28311552 bytes written to sentences.tar.bz2
# Downloading: 28377088 bytes written to sentences.tar.bz2
# Downloading: 28442624 bytes written to sentences.tar.bz2
# Downloading: 28508160 bytes written to sentences.tar.bz2
# Downloading: 28573696 bytes written to sentences.tar.bz2
# Downloading: 28639232 bytes written to sentences.tar.bz2
# Downloading: 28704768 bytes written to sentences.tar.bz2
# Downloading: 28770304 bytes written to sentences.tar.bz2
# Downloading: 28835840 bytes written to sentences.tar.bz2
# Downloading: 28901376 bytes written to sentences.tar.bz2
# Downloading: 28966912 bytes written to sentences.tar.bz2
# Downloading: 29032448 bytes written to sentences.tar.bz2
# Downloading: 29097984 bytes written to sentences.tar.bz2
# Downloading: 29163520 bytes written to sentences.tar.bz2
# Downloading: 29229056 bytes written to sentences.tar.bz2
# Downloading: 29294592 bytes written to sentences.tar.bz2
# Downloading: 29360128 bytes written to sentences.tar.bz2
# Downloading: 29425664 bytes written to sentences.tar.bz2
# Downloading: 29491200 bytes written to sentences.tar.bz2
# Downloading: 29556736 bytes written to sentences.tar.bz2
# Downloading: 29622272 bytes written to sentences.tar.bz2
# Downloading: 29687808 bytes written to sentences.tar.bz2
# Downloading: 29753344 bytes written to sentences.tar.bz2
# Downloading: 29818880 bytes written to sentences.tar.bz2
# Downloading: 29884416 bytes written to sentences.tar.bz2
# Downloading: 29949952 bytes written to sentences.tar.bz2
# Downloading: 30015488 bytes written to sentences.tar.bz2
# Downloading: 30081024 bytes written to sentences.tar.bz2
# Downloading: 30146560 bytes written to sentences.tar.bz2
# Downloading: 30212096 bytes written to sentences.tar.bz2
# Downloading: 30277632 bytes written to sentences.tar.bz2
# Downloading: 30343168 bytes written to sentences.tar.bz2
# Downloading: 30408704 bytes written to sentences.tar.bz2
# Downloading: 30474240 bytes written to sentences.tar.bz2
# Downloading: 30539776 bytes written to sentences.tar.bz2
# Downloading: 30605312 bytes written to sentences.tar.bz2
# Downloading: 30670848 bytes written to sentences.tar.bz2
# Downloading: 30736384 bytes written to sentences.tar.bz2
# Downloading: 30801920 bytes written to sentences.tar.bz2
# Downloading: 30867456 bytes written to sentences.tar.bz2
# Downloading: 30932992 bytes written to sentences.tar.bz2
# Downloading: 30998528 bytes written to sentences.tar.bz2
# Downloading: 31064064 bytes written to sentences.tar.bz2
# Downloading: 31129600 bytes written to sentences.tar.bz2
# Downloading: 31195136 bytes written to sentences.tar.bz2
# Downloading: 31260672 bytes written to sentences.tar.bz2
# Downloading: 31326208 bytes written to sentences.tar.bz2
# Downloading: 31391744 bytes written to sentences.tar.bz2
# Downloading: 31457280 bytes written to sentences.tar.bz2
# Downloading: 31522816 bytes written to sentences.tar.bz2
# Downloading: 31588352 bytes written to sentences.tar.bz2
# Downloading: 31653888 bytes written to sentences.tar.bz2
# Downloading: 31719424 bytes written to sentences.tar.bz2
# Downloading: 31784960 bytes written to sentences.tar.bz2
# Downloading: 31850496 bytes written to sentences.tar.bz2
# Downloading: 31916032 bytes written to sentences.tar.bz2
# Downloading: 31981568 bytes written to sentences.tar.bz2
# Downloading: 32047104 bytes written to sentences.tar.bz2
# Downloading: 32112640 bytes written to sentences.tar.bz2
# Downloading: 32178176 bytes written to sentences.tar.bz2
# Downloading: 32243712 bytes written to sentences.tar.bz2
# Downloading: 32309248 bytes written to sentences.tar.bz2
# Downloading: 32374784 bytes written to sentences.tar.bz2
# Downloading: 32440320 bytes written to sentences.tar.bz2
# Downloading: 32505856 bytes written to sentences.tar.bz2
# Downloading: 32571392 bytes written to sentences.tar.bz2
# Downloading: 32636928 bytes written to sentences.tar.bz2
# Downloading: 32702464 bytes written to sentences.tar.bz2
# Downloading: 32768000 bytes written to sentences.tar.bz2
# Downloading: 32833536 bytes written to sentences.tar.bz2
# Downloading: 32899072 bytes written to sentences.tar.bz2
# Downloading: 32964608 bytes written to sentences.tar.bz2
# Downloading: 33030144 bytes written to sentences.tar.bz2
# Downloading: 33095680 bytes written to sentences.tar.bz2
# Downloading: 33161216 bytes written to sentences.tar.bz2
# Downloading: 33226752 bytes written to sentences.tar.bz2
# Downloading: 33292288 bytes written to sentences.tar.bz2
# Downloading: 33357824 bytes written to sentences.tar.bz2
# Downloading: 33423360 bytes written to sentences.tar.bz2
# Downloading: 33488896 bytes written to sentences.tar.bz2
# Downloading: 33554432 bytes written to sentences.tar.bz2
# Downloading: 33619968 bytes written to sentences.tar.bz2
# Downloading: 33685504 bytes written to sentences.tar.bz2
# Downloading: 33751040 bytes written to sentences.tar.bz2
# Downloading: 33816576 bytes written to sentences.tar.bz2
# Downloading: 33882112 bytes written to sentences.tar.bz2
# Downloading: 33947648 bytes written to sentences.tar.bz2
# Downloading: 34013184 bytes written to sentences.tar.bz2
# Downloading: 34078720 bytes written to sentences.tar.bz2
# Downloading: 34144256 bytes written to sentences.tar.bz2
# Downloading: 34209792 bytes written to sentences.tar.bz2
# Downloading: 34275328 bytes written to sentences.tar.bz2
# Downloading: 34340864 bytes written to sentences.tar.bz2
# Downloading: 34406400 bytes written to sentences.tar.bz2
# Downloading: 34471936 bytes written to sentences.tar.bz2
# Downloading: 34537472 bytes written to sentences.tar.bz2
# Downloading: 34603008 bytes written to sentences.tar.bz2
# Downloading: 34668544 bytes written to sentences.tar.bz2
# Downloading: 34734080 bytes written to sentences.tar.bz2
# Downloading: 34799616 bytes written to sentences.tar.bz2
# Downloading: 34865152 bytes written to sentences.tar.bz2
# Downloading: 34930688 bytes written to sentences.tar.bz2
# Downloading: 34996224 bytes written to sentences.tar.bz2
# Downloading: 35061760 bytes written to sentences.tar.bz2
# Downloading: 35127296 bytes written to sentences.tar.bz2
# Downloading: 35192832 bytes written to sentences.tar.bz2
# Downloading: 35258368 bytes written to sentences.tar.bz2
# Downloading: 35323904 bytes written to sentences.tar.bz2
# Downloading: 35389440 bytes written to sentences.tar.bz2
# Downloading: 35454976 bytes written to sentences.tar.bz2
# Downloading: 35520512 bytes written to sentences.tar.bz2
# Downloading: 35586048 bytes written to sentences.tar.bz2
# Downloading: 35651584 bytes written to sentences.tar.bz2
# Downloading: 35717120 bytes written to sentences.tar.bz2
# Downloading: 35782656 bytes written to sentences.tar.bz2
# Downloading: 35848192 bytes written to sentences.tar.bz2
# Downloading: 35913728 bytes written to sentences.tar.bz2
# Downloading: 35979264 bytes written to sentences.tar.bz2
# Downloading: 36044800 bytes written to sentences.tar.bz2
# Downloading: 36110336 bytes written to sentences.tar.bz2
# Downloading: 36175872 bytes written to sentences.tar.bz2
# Downloading: 36241408 bytes written to sentences.tar.bz2
# Downloading: 36306944 bytes written to sentences.tar.bz2
# Downloading: 36372480 bytes written to sentences.tar.bz2
# Downloading: 36438016 bytes written to sentences.tar.bz2
# Downloading: 36503552 bytes written to sentences.tar.bz2
# Downloading: 36569088 bytes written to sentences.tar.bz2
# Downloading: 36634624 bytes written to sentences.tar.bz2
# Downloading: 36700160 bytes written to sentences.tar.bz2
# Downloading: 36765696 bytes written to sentences.tar.bz2
# Downloading: 36831232 bytes written to sentences.tar.bz2
# Downloading: 36896768 bytes written to sentences.tar.bz2
# Downloading: 36962304 bytes written to sentences.tar.bz2
# Downloading: 37027840 bytes written to sentences.tar.bz2
# Downloading: 37093376 bytes written to sentences.tar.bz2
# Downloading: 37158912 bytes written to sentences.tar.bz2
# Downloading: 37224448 bytes written to sentences.tar.bz2
# Downloading: 37289984 bytes written to sentences.tar.bz2
# Downloading: 37355520 bytes written to sentences.tar.bz2
# Downloading: 37421056 bytes written to sentences.tar.bz2
# Downloading: 37486592 bytes written to sentences.tar.bz2
# Downloading: 37552128 bytes written to sentences.tar.bz2
# Downloading: 37617664 bytes written to sentences.tar.bz2
# Downloading: 37683200 bytes written to sentences.tar.bz2
# Downloading: 37748736 bytes written to sentences.tar.bz2
# Downloading: 37814272 bytes written to sentences.tar.bz2
# Downloading: 37879808 bytes written to sentences.tar.bz2
# Downloading: 37945344 bytes written to sentences.tar.bz2
# Downloading: 38010880 bytes written to sentences.tar.bz2
# Downloading: 38076416 bytes written to sentences.tar.bz2
# Downloading: 38141952 bytes written to sentences.tar.bz2
# Downloading: 38207488 bytes written to sentences.tar.bz2
# Downloading: 38273024 bytes written to sentences.tar.bz2
# Downloading: 38338560 bytes written to sentences.tar.bz2
# Downloading: 38404096 bytes written to sentences.tar.bz2
# Downloading: 38469632 bytes written to sentences.tar.bz2
# Downloading: 38535168 bytes written to sentences.tar.bz2
# Downloading: 38600704 bytes written to sentences.tar.bz2
# Downloading: 38666240 bytes written to sentences.tar.bz2
# Downloading: 38731776 bytes written to sentences.tar.bz2
# Downloading: 38797312 bytes written to sentences.tar.bz2
# Downloading: 38862848 bytes written to sentences.tar.bz2
# Downloading: 38928384 bytes written to sentences.tar.bz2
# Downloading: 38993920 bytes written to sentences.tar.bz2
# Downloading: 39059456 bytes written to sentences.tar.bz2
# Downloading: 39124992 bytes written to sentences.tar.bz2
# Downloading: 39190528 bytes written to sentences.tar.bz2
# Downloading: 39256064 bytes written to sentences.tar.bz2
# Downloading: 39321600 bytes written to sentences.tar.bz2
# Downloading: 39387136 bytes written to sentences.tar.bz2
# Downloading: 39452672 bytes written to sentences.tar.bz2
# Downloading: 39518208 bytes written to sentences.tar.bz2
# Downloading: 39583744 bytes written to sentences.tar.bz2
# Downloading: 39649280 bytes written to sentences.tar.bz2
# Downloading: 39714816 bytes written to sentences.tar.bz2
# Downloading: 39780352 bytes written to sentences.tar.bz2
# Downloading: 39845888 bytes written to sentences.tar.bz2
# Downloading: 39911424 bytes written to sentences.tar.bz2
# Downloading: 39976960 bytes written to sentences.tar.bz2
# Downloading: 40042496 bytes written to sentences.tar.bz2
# Downloading: 40108032 bytes written to sentences.tar.bz2
# Downloading: 40173568 bytes written to sentences.tar.bz2
# Downloading: 40239104 bytes written to sentences.tar.bz2
# Downloading: 40304640 bytes written to sentences.tar.bz2
# Downloading: 40370176 bytes written to sentences.tar.bz2
# Downloading: 40435712 bytes written to sentences.tar.bz2
# Downloading: 40501248 bytes written to sentences.tar.bz2
# Downloading: 40566784 bytes written to sentences.tar.bz2
# Downloading: 40632320 bytes written to sentences.tar.bz2
# Downloading: 40697856 bytes written to sentences.tar.bz2
# Downloading: 40763392 bytes written to sentences.tar.bz2
# Downloading: 40828928 bytes written to sentences.tar.bz2
# Downloading: 40894464 bytes written to sentences.tar.bz2
# Downloading: 40960000 bytes written to sentences.tar.bz2
# Downloading: 41025536 bytes written to sentences.tar.bz2
# Downloading: 41091072 bytes written to sentences.tar.bz2
# Downloading: 41156608 bytes written to sentences.tar.bz2
# Downloading: 41222144 bytes written to sentences.tar.bz2
# Downloading: 41287680 bytes written to sentences.tar.bz2
# Downloading: 41353216 bytes written to sentences.tar.bz2
# Downloading: 41418752 bytes written to sentences.tar.bz2
# Downloading: 41484288 bytes written to sentences.tar.bz2
# Downloading: 41549824 bytes written to sentences.tar.bz2
# Downloading: 41615360 bytes written to sentences.tar.bz2
# Downloading: 41680896 bytes written to sentences.tar.bz2
# Downloading: 41746432 bytes written to sentences.tar.bz2
# Downloading: 41811968 bytes written to sentences.tar.bz2
# Downloading: 41877504 bytes written to sentences.tar.bz2
# Downloading: 41943040 bytes written to sentences.tar.bz2
# Downloading: 42008576 bytes written to sentences.tar.bz2
# Downloading: 42074112 bytes written to sentences.tar.bz2
# Downloading: 42139648 bytes written to sentences.tar.bz2
# Downloading: 42205184 bytes written to sentences.tar.bz2
# Downloading: 42270720 bytes written to sentences.tar.bz2
# Downloading: 42336256 bytes written to sentences.tar.bz2
# Downloading: 42401792 bytes written to sentences.tar.bz2
# Downloading: 42467328 bytes written to sentences.tar.bz2
# Downloading: 42532864 bytes written to sentences.tar.bz2
# Downloading: 42598400 bytes written to sentences.tar.bz2
# Downloading: 42663936 bytes written to sentences.tar.bz2
# Downloading: 42729472 bytes written to sentences.tar.bz2
# Downloading: 42795008 bytes written to sentences.tar.bz2
# Downloading: 42860544 bytes written to sentences.tar.bz2
# Downloading: 42926080 bytes written to sentences.tar.bz2
# Downloading: 42991616 bytes written to sentences.tar.bz2
# Downloading: 43057152 bytes written to sentences.tar.bz2
# Downloading: 43122688 bytes written to sentences.tar.bz2
# Downloading: 43188224 bytes written to sentences.tar.bz2
# Downloading: 43253760 bytes written to sentences.tar.bz2
# Downloading: 43319296 bytes written to sentences.tar.bz2
# Downloading: 43384832 bytes written to sentences.tar.bz2
# Downloading: 43450368 bytes written to sentences.tar.bz2
# Downloading: 43515904 bytes written to sentences.tar.bz2
# Downloading: 43581440 bytes written to sentences.tar.bz2
# Downloading: 43646976 bytes written to sentences.tar.bz2
# Downloading: 43712512 bytes written to sentences.tar.bz2
# Downloading: 43778048 bytes written to sentences.tar.bz2
# Downloading: 43843584 bytes written to sentences.tar.bz2
# Downloading: 43909120 bytes written to sentences.tar.bz2
# Downloading: 43974656 bytes written to sentences.tar.bz2
# Downloading: 44040192 bytes written to sentences.tar.bz2
# Downloading: 44105728 bytes written to sentences.tar.bz2
# Downloading: 44171264 bytes written to sentences.tar.bz2
# Downloading: 44236800 bytes written to sentences.tar.bz2
# Downloading: 44302336 bytes written to sentences.tar.bz2
# Downloading: 44367872 bytes written to sentences.tar.bz2
# Downloading: 44433408 bytes written to sentences.tar.bz2
# Downloading: 44498944 bytes written to sentences.tar.bz2
# Downloading: 44564480 bytes written to sentences.tar.bz2
# Downloading: 44630016 bytes written to sentences.tar.bz2
# Downloading: 44695552 bytes written to sentences.tar.bz2
# Downloading: 44761088 bytes written to sentences.tar.bz2
# Downloading: 44826624 bytes written to sentences.tar.bz2
# Downloading: 44892160 bytes written to sentences.tar.bz2
# Downloading: 44957696 bytes written to sentences.tar.bz2
# Downloading: 45023232 bytes written to sentences.tar.bz2
# Downloading: 45088768 bytes written to sentences.tar.bz2
# Downloading: 45154304 bytes written to sentences.tar.bz2
# Downloading: 45219840 bytes written to sentences.tar.bz2
# Downloading: 45285376 bytes written to sentences.tar.bz2
# Downloading: 45350912 bytes written to sentences.tar.bz2
# Downloading: 45416448 bytes written to sentences.tar.bz2
# Downloading: 45481984 bytes written to sentences.tar.bz2
# Downloading: 45547520 bytes written to sentences.tar.bz2
# Downloading: 45613056 bytes written to sentences.tar.bz2
# Downloading: 45678592 bytes written to sentences.tar.bz2
# Downloading: 45744128 bytes written to sentences.tar.bz2
# Downloading: 45809664 bytes written to sentences.tar.bz2
# Downloading: 45875200 bytes written to sentences.tar.bz2
# Downloading: 45940736 bytes written to sentences.tar.bz2
# Downloading: 46006272 bytes written to sentences.tar.bz2
# Downloading: 46071808 bytes written to sentences.tar.bz2
# Downloading: 46137344 bytes written to sentences.tar.bz2
# Downloading: 46202880 bytes written to sentences.tar.bz2
# Downloading: 46268416 bytes written to sentences.tar.bz2
# Downloading: 46333952 bytes written to sentences.tar.bz2
# Downloading: 46399488 bytes written to sentences.tar.bz2
# Downloading: 46465024 bytes written to sentences.tar.bz2
# Downloading: 46530560 bytes written to sentences.tar.bz2
# Downloading: 46596096 bytes written to sentences.tar.bz2
# Downloading: 46661632 bytes written to sentences.tar.bz2
# Downloading: 46727168 bytes written to sentences.tar.bz2
# Downloading: 46792704 bytes written to sentences.tar.bz2
# Downloading: 46858240 bytes written to sentences.tar.bz2
# Downloading: 46923776 bytes written to sentences.tar.bz2
# Downloading: 46989312 bytes written to sentences.tar.bz2
# Downloading: 47054848 bytes written to sentences.tar.bz2
# Downloading: 47120384 bytes written to sentences.tar.bz2
# Downloading: 47185920 bytes written to sentences.tar.bz2
# Downloading: 47251456 bytes written to sentences.tar.bz2
# Downloading: 47316992 bytes written to sentences.tar.bz2
# Downloading: 47382528 bytes written to sentences.tar.bz2
# Downloading: 47448064 bytes written to sentences.tar.bz2
# Downloading: 47513600 bytes written to sentences.tar.bz2
# Downloading: 47579136 bytes written to sentences.tar.bz2
# Downloading: 47644672 bytes written to sentences.tar.bz2
# Downloading: 47710208 bytes written to sentences.tar.bz2
# Downloading: 47775744 bytes written to sentences.tar.bz2
# Downloading: 47841280 bytes written to sentences.tar.bz2
# Downloading: 47906816 bytes written to sentences.tar.bz2
# Downloading: 47972352 bytes written to sentences.tar.bz2
# Downloading: 48037888 bytes written to sentences.tar.bz2
# Downloading: 48103424 bytes written to sentences.tar.bz2
# Downloading: 48168960 bytes written to sentences.tar.bz2
# Downloading: 48234496 bytes written to sentences.tar.bz2
# Downloading: 48300032 bytes written to sentences.tar.bz2
# Downloading: 48365568 bytes written to sentences.tar.bz2
# Downloading: 48431104 bytes written to sentences.tar.bz2
# Downloading: 48496640 bytes written to sentences.tar.bz2
# Downloading: 48562176 bytes written to sentences.tar.bz2
# Downloading: 48627712 bytes written to sentences.tar.bz2
# Downloading: 48693248 bytes written to sentences.tar.bz2
# Downloading: 48758784 bytes written to sentences.tar.bz2
# Downloading: 48824320 bytes written to sentences.tar.bz2
# Downloading: 48889856 bytes written to sentences.tar.bz2
# Downloading: 48955392 bytes written to sentences.tar.bz2
# Downloading: 49020928 bytes written to sentences.tar.bz2
# Downloading: 49086464 bytes written to sentences.tar.bz2
# Downloading: 49152000 bytes written to sentences.tar.bz2
# Downloading: 49217536 bytes written to sentences.tar.bz2
# Downloading: 49283072 bytes written to sentences.tar.bz2
# Downloading: 49348608 bytes written to sentences.tar.bz2
# Downloading: 49414144 bytes written to sentences.tar.bz2
# Downloading: 49479680 bytes written to sentences.tar.bz2
# Downloading: 49545216 bytes written to sentences.tar.bz2
# Downloading: 49610752 bytes written to sentences.tar.bz2
# Downloading: 49676288 bytes written to sentences.tar.bz2
# Downloading: 49741824 bytes written to sentences.tar.bz2
# Downloading: 49807360 bytes written to sentences.tar.bz2
# Downloading: 49872896 bytes written to sentences.tar.bz2
# Downloading: 49938432 bytes written to sentences.tar.bz2
# Downloading: 50003968 bytes written to sentences.tar.bz2
# Downloading: 50069504 bytes written to sentences.tar.bz2
# Downloading: 50135040 bytes written to sentences.tar.bz2
# Downloading: 50200576 bytes written to sentences.tar.bz2
# Downloading: 50266112 bytes written to sentences.tar.bz2
# Downloading: 50331648 bytes written to sentences.tar.bz2
# Downloading: 50397184 bytes written to sentences.tar.bz2
# Downloading: 50462720 bytes written to sentences.tar.bz2
# Downloading: 50528256 bytes written to sentences.tar.bz2
# Downloading: 50593792 bytes written to sentences.tar.bz2
# Downloading: 50659328 bytes written to sentences.tar.bz2
# Downloading: 50724864 bytes written to sentences.tar.bz2
# Downloading: 50790400 bytes written to sentences.tar.bz2
# Downloading: 50855936 bytes written to sentences.tar.bz2
# Downloading: 50921472 bytes written to sentences.tar.bz2
# Downloading: 50987008 bytes written to sentences.tar.bz2
# Downloading: 51052544 bytes written to sentences.tar.bz2
# Downloading: 51118080 bytes written to sentences.tar.bz2
# Downloading: 51183616 bytes written to sentences.tar.bz2
# Downloading: 51249152 bytes written to sentences.tar.bz2
# Downloading: 51314688 bytes written to sentences.tar.bz2
# Downloading: 51380224 bytes written to sentences.tar.bz2
# Downloading: 51445760 bytes written to sentences.tar.bz2
# Downloading: 51511296 bytes written to sentences.tar.bz2
# Downloading: 51576832 bytes written to sentences.tar.bz2
# Downloading: 51642368 bytes written to sentences.tar.bz2
# Downloading: 51707904 bytes written to sentences.tar.bz2
# Downloading: 51773440 bytes written to sentences.tar.bz2
# Downloading: 51838976 bytes written to sentences.tar.bz2
# Downloading: 51904512 bytes written to sentences.tar.bz2
# Downloading: 51970048 bytes written to sentences.tar.bz2
# Downloading: 52035584 bytes written to sentences.tar.bz2
# Downloading: 52101120 bytes written to sentences.tar.bz2
# Downloading: 52166656 bytes written to sentences.tar.bz2
# Downloading: 52232192 bytes written to sentences.tar.bz2
# Downloading: 52297728 bytes written to sentences.tar.bz2
# Downloading: 52363264 bytes written to sentences.tar.bz2
# Downloading: 52428800 bytes written to sentences.tar.bz2
# Downloading: 52494336 bytes written to sentences.tar.bz2
# Downloading: 52559872 bytes written to sentences.tar.bz2
# Downloading: 52625408 bytes written to sentences.tar.bz2
# Downloading: 52690944 bytes written to sentences.tar.bz2
# Downloading: 52756480 bytes written to sentences.tar.bz2
# Downloading: 52822016 bytes written to sentences.tar.bz2
# Downloading: 52887552 bytes written to sentences.tar.bz2
# Downloading: 52953088 bytes written to sentences.tar.bz2
# Downloading: 53018624 bytes written to sentences.tar.bz2
# Downloading: 53084160 bytes written to sentences.tar.bz2
# Downloading: 53149696 bytes written to sentences.tar.bz2
# Downloading: 53215232 bytes written to sentences.tar.bz2
# Downloading: 53280768 bytes written to sentences.tar.bz2
# Downloading: 53346304 bytes written to sentences.tar.bz2
# Downloading: 53411840 bytes written to sentences.tar.bz2
# Downloading: 53477376 bytes written to sentences.tar.bz2
# Downloading: 53542912 bytes written to sentences.tar.bz2
# Downloading: 53608448 bytes written to sentences.tar.bz2
# Downloading: 53673984 bytes written to sentences.tar.bz2
# Downloading: 53739520 bytes written to sentences.tar.bz2
# Downloading: 53805056 bytes written to sentences.tar.bz2
# Downloading: 53870592 bytes written to sentences.tar.bz2
# Downloading: 53936128 bytes written to sentences.tar.bz2
# Downloading: 54001664 bytes written to sentences.tar.bz2
# Downloading: 54067200 bytes written to sentences.tar.bz2
# Downloading: 54132736 bytes written to sentences.tar.bz2
# Downloading: 54198272 bytes written to sentences.tar.bz2
# Downloading: 54263808 bytes written to sentences.tar.bz2
# Downloading: 54329344 bytes written to sentences.tar.bz2
# Downloading: 54394880 bytes written to sentences.tar.bz2
# Downloading: 54460416 bytes written to sentences.tar.bz2
# Downloading: 54525952 bytes written to sentences.tar.bz2
# Downloading: 54591488 bytes written to sentences.tar.bz2
# Downloading: 54657024 bytes written to sentences.tar.bz2
# Downloading: 54722560 bytes written to sentences.tar.bz2
# Downloading: 54788096 bytes written to sentences.tar.bz2
# Downloading: 54853632 bytes written to sentences.tar.bz2
# Downloading: 54919168 bytes written to sentences.tar.bz2
# Downloading: 54984704 bytes written to sentences.tar.bz2
# Downloading: 55050240 bytes written to sentences.tar.bz2
# Downloading: 55115776 bytes written to sentences.tar.bz2
# Downloading: 55181312 bytes written to sentences.tar.bz2
# Downloading: 55246848 bytes written to sentences.tar.bz2
# Downloading: 55312384 bytes written to sentences.tar.bz2
# Downloading: 55377920 bytes written to sentences.tar.bz2
# ...
# Downloading: 172294144 bytes written to sentences.tar.bz2
# Downloading: 172359680 bytes written to sentences.tar.bz2
# Downloading: 172425216 bytes written to sentences.tar.bz2
# Downloading: 172490752 bytes written to sentences.tar.bz2
# Downloading: 172556288 bytes written to sentences.tar.bz2
# Downloading: 172621824 bytes written to sentences.tar.bz2
# Downloading: 172687360 bytes written to sentences.tar.bz2
# Downloading: 172752896 bytes written to sentences.tar.bz2
# Downloading: 172818432 bytes written to sentences.tar.bz2
# Downloading: 172883968 bytes written to sentences.tar.bz2
# Downloading: 172949504 bytes written to sentences.tar.bz2
# Downloading: 173015040 bytes written to sentences.tar.bz2
# Downloading: 173080576 bytes written to sentences.tar.bz2
# Downloading: 173146112 bytes written to sentences.tar.bz2
# Downloading: 173211648 bytes written to sentences.tar.bz2
# Downloading: 173277184 bytes written to sentences.tar.bz2
# Downloading: 173342720 bytes written to sentences.tar.bz2
# Downloading: 173408256 bytes written to sentences.tar.bz2
# Downloading: 173473792 bytes written to sentences.tar.bz2
# Downloading: 173539328 bytes written to sentences.tar.bz2
# Downloading: 173604864 bytes written to sentences.tar.bz2
# Downloading: 173670400 bytes written to sentences.tar.bz2
# Downloading: 173735936 bytes written to sentences.tar.bz2
# Downloading: 173801472 bytes written to sentences.tar.bz2
# Downloading: 173867008 bytes written to sentences.tar.bz2
# Downloading: 173932544 bytes written to sentences.tar.bz2
# Downloading: 173998080 bytes written to sentences.tar.bz2
# Downloading: 174063616 bytes written to sentences.tar.bz2
# Downloading: 174129152 bytes written to sentences.tar.bz2
# Downloading: 174194688 bytes written to sentences.tar.bz2
# Downloading: 174260224 bytes written to sentences.tar.bz2
# Downloading: 174325760 bytes written to sentences.tar.bz2
# Downloading: 174391296 bytes written to sentences.tar.bz2
# Downloading: 174456832 bytes written to sentences.tar.bz2
# Downloading: 174522368 bytes written to sentences.tar.bz2
# Downloading: 174587904 bytes written to sentences.tar.bz2
# Downloading: 174653440 bytes written to sentences.tar.bz2
# Downloading: 174718976 bytes written to sentences.tar.bz2
# Downloading: 174784512 bytes written to sentences.tar.bz2
# Downloading: 174850048 bytes written to sentences.tar.bz2
# Downloading: 174915584 bytes written to sentences.tar.bz2
# Downloading: 174981120 bytes written to sentences.tar.bz2
# Downloading: 175046656 bytes written to sentences.tar.bz2
# Downloading: 175112192 bytes written to sentences.tar.bz2
# Downloading: 175177728 bytes written to sentences.tar.bz2
# Downloading: 175243264 bytes written to sentences.tar.bz2
# Downloading: 175308800 bytes written to sentences.tar.bz2
# Downloading: 175374336 bytes written to sentences.tar.bz2
# Downloading: 175439872 bytes written to sentences.tar.bz2
# Downloading: 175505408 bytes written to sentences.tar.bz2
# Downloading: 175570944 bytes written to sentences.tar.bz2
# Downloading: 175636480 bytes written to sentences.tar.bz2
# Downloading: 175702016 bytes written to sentences.tar.bz2
# Downloading: 175767552 bytes written to sentences.tar.bz2
# Downloading: 175833088 bytes written to sentences.tar.bz2
# Downloading: 175898624 bytes written to sentences.tar.bz2
# Downloading: 175964160 bytes written to sentences.tar.bz2
# Downloading: 176029696 bytes written to sentences.tar.bz2
# Downloading: 176095232 bytes written to sentences.tar.bz2
# Downloading: 176160768 bytes written to sentences.tar.bz2
# Downloading: 176226304 bytes written to sentences.tar.bz2
# Downloading: 176291840 bytes written to sentences.tar.bz2
# Downloading: 176357376 bytes written to sentences.tar.bz2
# Downloading: 176422912 bytes written to sentences.tar.bz2
# Downloading: 176488448 bytes written to sentences.tar.bz2
# Downloading: 176553984 bytes written to sentences.tar.bz2
# Downloading: 176619520 bytes written to sentences.tar.bz2
# Downloading: 176685056 bytes written to sentences.tar.bz2
# Downloading: 176750592 bytes written to sentences.tar.bz2
# Downloading: 176816128 bytes written to sentences.tar.bz2
# Downloading: 176881664 bytes written to sentences.tar.bz2
# Downloading: 176947200 bytes written to sentences.tar.bz2
# Downloading: 177012736 bytes written to sentences.tar.bz2
# Downloading: 177078272 bytes written to sentences.tar.bz2
# Downloading: 177143808 bytes written to sentences.tar.bz2
# Downloading: 177209344 bytes written to sentences.tar.bz2
# Downloading: 177274880 bytes written to sentences.tar.bz2
# Downloading: 177340416 bytes written to sentences.tar.bz2
# Downloading: 177405952 bytes written to sentences.tar.bz2
# Downloading: 177471488 bytes written to sentences.tar.bz2
# Downloading: 177537024 bytes written to sentences.tar.bz2
# Downloading: 177602560 bytes written to sentences.tar.bz2
# Downloading: 177668096 bytes written to sentences.tar.bz2
# Downloading: 177733632 bytes written to sentences.tar.bz2
# Downloading: 177799168 bytes written to sentences.tar.bz2
# Downloading: 177864704 bytes written to sentences.tar.bz2
# Downloading: 177930240 bytes written to sentences.tar.bz2
# Downloading: 177995776 bytes written to sentences.tar.bz2
# Downloading: 178061312 bytes written to sentences.tar.bz2
# Downloading: 178126848 bytes written to sentences.tar.bz2
# Downloading: 178192384 bytes written to sentences.tar.bz2
# Downloading: 178257920 bytes written to sentences.tar.bz2
# Downloading: 178323456 bytes written to sentences.tar.bz2
# Downloading: 178388992 bytes written to sentences.tar.bz2
# Downloading: 178454528 bytes written to sentences.tar.bz2
# Downloading: 178520064 bytes written to sentences.tar.bz2
# Downloading: 178585600 bytes written to sentences.tar.bz2
# Downloading: 178651136 bytes written to sentences.tar.bz2
# Downloading: 178716672 bytes written to sentences.tar.bz2
# Downloading: 178782208 bytes written to sentences.tar.bz2
# Downloading: 178847744 bytes written to sentences.tar.bz2
# Downloading: 178913280 bytes written to sentences.tar.bz2
# Downloading: 178978816 bytes written to sentences.tar.bz2
# Downloading: 179044352 bytes written to sentences.tar.bz2
# Downloading: 179109888 bytes written to sentences.tar.bz2
# Downloading: 179175424 bytes written to sentences.tar.bz2
# Downloading: 179240960 bytes written to sentences.tar.bz2
# Downloading: 179306496 bytes written to sentences.tar.bz2
# Downloading: 179372032 bytes written to sentences.tar.bz2
# Downloading: 179437568 bytes written to sentences.tar.bz2
# Downloading: 179503104 bytes written to sentences.tar.bz2
# Downloading: 179568640 bytes written to sentences.tar.bz2
# Downloading: 179634176 bytes written to sentences.tar.bz2
# Downloading: 179699712 bytes written to sentences.tar.bz2
# Downloading: 179765248 bytes written to sentences.tar.bz2
# Downloading: 179830784 bytes written to sentences.tar.bz2
# Downloading: 179896320 bytes written to sentences.tar.bz2
# Downloading: 179961856 bytes written to sentences.tar.bz2
# Downloading: 180027392 bytes written to sentences.tar.bz2
# Downloading: 180092928 bytes written to sentences.tar.bz2
# Downloading: 180158464 bytes written to sentences.tar.bz2
# Downloading: 180224000 bytes written to sentences.tar.bz2
# Downloading: 180289536 bytes written to sentences.tar.bz2
# Downloading: 180355072 bytes written to sentences.tar.bz2
# Downloading: 180420608 bytes written to sentences.tar.bz2
# Downloading: 180486144 bytes written to sentences.tar.bz2
# Downloading: 180551680 bytes written to sentences.tar.bz2
# Downloading: 180617216 bytes written to sentences.tar.bz2
# Downloading: 180682752 bytes written to sentences.tar.bz2
# Downloading: 180748288 bytes written to sentences.tar.bz2
# Downloading: 180813824 bytes written to sentences.tar.bz2
# Downloading: 180879360 bytes written to sentences.tar.bz2
# Downloading: 180944896 bytes written to sentences.tar.bz2
# Downloading: 181010432 bytes written to sentences.tar.bz2
# Downloading: 181075968 bytes written to sentences.tar.bz2
# Downloading: 181141504 bytes written to sentences.tar.bz2
# Downloading: 181207040 bytes written to sentences.tar.bz2
# Downloading: 181272576 bytes written to sentences.tar.bz2
# Downloading: 181338112 bytes written to sentences.tar.bz2
# Downloading: 181403648 bytes written to sentences.tar.bz2
# Downloading: 181469184 bytes written to sentences.tar.bz2
# Downloading: 181534720 bytes written to sentences.tar.bz2
# Downloading: 181600256 bytes written to sentences.tar.bz2
# Downloading: 181665792 bytes written to sentences.tar.bz2
# Downloading: 181731328 bytes written to sentences.tar.bz2
# Downloading: 181796864 bytes written to sentences.tar.bz2
# Downloading: 181862400 bytes written to sentences.tar.bz2
# Downloading: 181927936 bytes written to sentences.tar.bz2
# Downloading: 181993472 bytes written to sentences.tar.bz2
# Downloading: 182059008 bytes written to sentences.tar.bz2
# Downloading: 182124544 bytes written to sentences.tar.bz2
# Downloading: 182190080 bytes written to sentences.tar.bz2
# Downloading: 182255616 bytes written to sentences.tar.bz2
# Downloading: 182321152 bytes written to sentences.tar.bz2
# Downloading: 182386688 bytes written to sentences.tar.bz2
# Downloading: 182452224 bytes written to sentences.tar.bz2
# Downloading: 182517760 bytes written to sentences.tar.bz2
# Downloading: 182583296 bytes written to sentences.tar.bz2
# Downloading: 182648832 bytes written to sentences.tar.bz2
# Downloading: 182714368 bytes written to sentences.tar.bz2
# Downloading: 182779904 bytes written to sentences.tar.bz2
# Downloading: 182845440 bytes written to sentences.tar.bz2
# Downloading: 182910976 bytes written to sentences.tar.bz2
# Downloading: 182976512 bytes written to sentences.tar.bz2
# Downloading: 183042048 bytes written to sentences.tar.bz2
# Downloading: 183107584 bytes written to sentences.tar.bz2
# Downloading: 183173120 bytes written to sentences.tar.bz2
# Downloading: 183238656 bytes written to sentences.tar.bz2
# Downloading: 183304192 bytes written to sentences.tar.bz2
# Downloading: 183369728 bytes written to sentences.tar.bz2
# Downloading: 183435264 bytes written to sentences.tar.bz2
# Downloading: 183500800 bytes written to sentences.tar.bz2
# Downloading: 183566336 bytes written to sentences.tar.bz2
# Downloading: 183631872 bytes written to sentences.tar.bz2
# Downloading: 183697408 bytes written to sentences.tar.bz2
# Downloading: 183762944 bytes written to sentences.tar.bz2
# Downloading: 183828480 bytes written to sentences.tar.bz2
# Downloading: 183894016 bytes written to sentences.tar.bz2
# Downloading: 183959552 bytes written to sentences.tar.bz2
# Downloading: 184025088 bytes written to sentences.tar.bz2
# Downloading: 184090624 bytes written to sentences.tar.bz2
# Downloading: 184156160 bytes written to sentences.tar.bz2
# Downloading: 184221696 bytes written to sentences.tar.bz2
# Downloading: 184287232 bytes written to sentences.tar.bz2
# Downloading: 184352768 bytes written to sentences.tar.bz2
# Downloading: 184418304 bytes written to sentences.tar.bz2
# Downloading: 184483840 bytes written to sentences.tar.bz2
# Downloading: 184549376 bytes written to sentences.tar.bz2
# Downloading: 184614912 bytes written to sentences.tar.bz2
# Downloading: 184680448 bytes written to sentences.tar.bz2
# Downloading: 184745984 bytes written to sentences.tar.bz2
# Downloading: 184811520 bytes written to sentences.tar.bz2
# Downloading: 184877056 bytes written to sentences.tar.bz2
# Downloading: 184942592 bytes written to sentences.tar.bz2
# Downloading: 185008128 bytes written to sentences.tar.bz2
# Downloading: 185073664 bytes written to sentences.tar.bz2
# Downloading: 185139200 bytes written to sentences.tar.bz2
# Downloading: 185204736 bytes written to sentences.tar.bz2
# Downloading: 185270272 bytes written to sentences.tar.bz2
# Downloading: 185335808 bytes written to sentences.tar.bz2
# Downloading: 185401344 bytes written to sentences.tar.bz2
# Downloading: 185466880 bytes written to sentences.tar.bz2
# Downloading: 185532416 bytes written to sentences.tar.bz2
# Downloading: 185597952 bytes written to sentences.tar.bz2
# Downloading: 185663488 bytes written to sentences.tar.bz2
# Downloading: 185729024 bytes written to sentences.tar.bz2
# Downloading: 185794560 bytes written to sentences.tar.bz2
# Downloading: 185860096 bytes written to sentences.tar.bz2
# Downloading: 185925632 bytes written to sentences.tar.bz2
# Downloading: 185991168 bytes written to sentences.tar.bz2
# Downloading: 186056704 bytes written to sentences.tar.bz2
# Downloading: 186122240 bytes written to sentences.tar.bz2
# Downloading: 186187776 bytes written to sentences.tar.bz2
# Downloading: 186253312 bytes written to sentences.tar.bz2
# Downloading: 186318848 bytes written to sentences.tar.bz2
# Downloading: 186384384 bytes written to sentences.tar.bz2
# Downloading: 186449920 bytes written to sentences.tar.bz2
# Downloading: 186515456 bytes written to sentences.tar.bz2
# Downloading: 186580992 bytes written to sentences.tar.bz2
# Downloading: 186646528 bytes written to sentences.tar.bz2
# Downloading: 186712064 bytes written to sentences.tar.bz2
# Downloading: 186777600 bytes written to sentences.tar.bz2
# Downloading: 186843136 bytes written to sentences.tar.bz2
# Downloading: 186908672 bytes written to sentences.tar.bz2
# Downloading: 186974208 bytes written to sentences.tar.bz2
# Downloading: 187039744 bytes written to sentences.tar.bz2
# Downloading: 187105280 bytes written to sentences.tar.bz2
# Downloading: 187170816 bytes written to sentences.tar.bz2
# Downloading: 187236352 bytes written to sentences.tar.bz2
# Downloading: 187301888 bytes written to sentences.tar.bz2
# Downloading: 187367424 bytes written to sentences.tar.bz2
# Downloading: 187432960 bytes written to sentences.tar.bz2
# Downloading: 187498496 bytes written to sentences.tar.bz2
# Downloading: 187564032 bytes written to sentences.tar.bz2
# Downloading: 187629568 bytes written to sentences.tar.bz2
# Downloading: 187695104 bytes written to sentences.tar.bz2
# Downloading: 187760640 bytes written to sentences.tar.bz2
# Downloading: 187826176 bytes written to sentences.tar.bz2
# Downloading: 187891712 bytes written to sentences.tar.bz2
# Downloading: 187957248 bytes written to sentences.tar.bz2
# Downloading: 188022784 bytes written to sentences.tar.bz2
# Downloading: 188088320 bytes written to sentences.tar.bz2
# Downloading: 188153856 bytes written to sentences.tar.bz2
# Downloading: 188219392 bytes written to sentences.tar.bz2
# Downloading: 188284928 bytes written to sentences.tar.bz2
# Downloading: 188350464 bytes written to sentences.tar.bz2
# Downloading: 188416000 bytes written to sentences.tar.bz2
# Downloading: 188481536 bytes written to sentences.tar.bz2
# Downloading: 188547072 bytes written to sentences.tar.bz2
# Downloading: 188612608 bytes written to sentences.tar.bz2
# Downloading: 188678144 bytes written to sentences.tar.bz2
# Downloading: 188743680 bytes written to sentences.tar.bz2
# Downloading: 188809216 bytes written to sentences.tar.bz2
# Downloading: 188874752 bytes written to sentences.tar.bz2
# Downloading: 188940288 bytes written to sentences.tar.bz2
# Downloading: 189005824 bytes written to sentences.tar.bz2
# Downloading: 189071360 bytes written to sentences.tar.bz2
# Downloading: 189136896 bytes written to sentences.tar.bz2
# Downloading: 189202432 bytes written to sentences.tar.bz2
# Downloading: 189267968 bytes written to sentences.tar.bz2
# Downloading: 189333504 bytes written to sentences.tar.bz2
# Downloading: 189399040 bytes written to sentences.tar.bz2
# Downloading: 189464576 bytes written to sentences.tar.bz2
# Downloading: 189530112 bytes written to sentences.tar.bz2
# Downloading: 189595648 bytes written to sentences.tar.bz2
# Downloading: 189661184 bytes written to sentences.tar.bz2
# Downloading: 189726720 bytes written to sentences.tar.bz2
# Downloading: 189792256 bytes written to sentences.tar.bz2
# Downloading: 189857792 bytes written to sentences.tar.bz2
# Downloading: 189923328 bytes written to sentences.tar.bz2
# Downloading: 189988864 bytes written to sentences.tar.bz2
# Downloading: 190054400 bytes written to sentences.tar.bz2
# Downloading: 190119936 bytes written to sentences.tar.bz2
# Downloading: 190151691 bytes written to sentences.tar.bz2
# sentences.tar.bz2 downloaded.
# sentences.tar.bz2 extracted to 'datasets/'.

# %%
dataset = open(FOLDER + 'sentences.csv', encoding='utf-8').read().strip().split('\n')

# %%
# Clean the data

dataset = list(map(lambda x: tuple(map(str.strip, x.split('\t'))), dataset))

# %%
from collections import Counter
counter = Counter(map(lambda x: x[1], dataset))

# %%
# Limit the amount of languages and data to use to limit computational costs

MAX_LANGS = 6
MAX_DOCS  = 50000

langs = [lang for (lang, _) in counter.most_common(MAX_LANGS)]

# %%
from collections import defaultdict

items_by_lang = defaultdict(list)

for item in dataset:
    lang = item[1]
    items_by_lang[lang].append(item)

dataset = [item for lang in langs for item in items_by_lang[lang][:MAX_DOCS]]

# %%
random.shuffle(dataset)

# %%
# N-grams to allow bag-of-words

def ngrams(sentence, n=1, lc=True):
    if lc:
        sentence = sentence.lower()
    length = len(sentence)

    return [sentence[i:i + n] for i in range(length - n + 1)] if n > 0 else []

# %%
def all_ngrams(sentence, max_ngram=3, lc=True):
    all_ngrams = []

    for i in range(1, max_ngram + 1):
        all_ngrams += [ngrams(sentence, n=i, lc=lc)]

    return all_ngrams

# %%
MAX_CHARS = 521
MAX_BIGRAMS = 1031
MAX_TRIGRAMS = 1031

# %%
# for debugging purposes

def reproducible_hash(string):

    h = hashlib.md5(string.encode("utf-8"), usedforsecurity=False)
    return int.from_bytes(h.digest()[0:8], 'big', signed=True)

# %%
MAXES = [MAX_CHARS, MAX_BIGRAMS, MAX_TRIGRAMS]

# %%
# use hash trick to limit space usage

def hash_ngrams(ngrams, modulos):
   #return [list(map(lambda x: reproducible_hash(x) % modulos[i], ngrams[i])) for i in range(len(modulos))]
   return [ [ reproducible_hash(string) % modulo for string in ngram ] for ngram, modulo in zip(ngrams, modulos) ]

# %%
# use relative frequencies instead of true embeddings (computationally costly)

def calc_rel_freq(codes):
    length = len(codes)
    counts = Counter(codes)

    for key in counts:
        counts[key] /= length

    return counts

# %%
MAX_SHIFT = []
for i in range(len(MAXES)):
    MAX_SHIFT += [sum(MAXES[:i])]

# %%
def shift_keys(dicts, MAX_SHIFT):
    return { key + shift: val for ngram, shift in zip(dicts, MAX_SHIFT) for (key, val) in ngram.items() }

# %%
def build_freq_dict(sentence, MAXES=MAXES, MAX_SHIFT=MAX_SHIFT):
    hngrams = hash_ngrams(all_ngrams(sentence), MAXES)
    fhcodes = map(calc_rel_freq, hngrams)
    return shift_keys(fhcodes, MAX_SHIFT)

# %%
dataset_num = []
for datapoint in tqdm(dataset):
    dataset_num += [list(datapoint) + [build_freq_dict(datapoint[2])]]
# Out:
#  61%|██████    | 182202/300000 [01:11<00:43, 2686.01it/s]

# %%
X_cat = [ dataset[3] for dataset in dataset_num ]

# %%
vectorizer = DictVectorizer(sparse=False)

X = vectorizer.fit_transform(X_cat)

# %%
y_cat = [ dataset[1] for dataset in dataset_num ]

# %%
y_symbols = set(y_cat)

idx2lang = {}
lang2idx = {}

for idx, lang in enumerate(y_symbols):
    idx2lang[idx]  = lang
    lang2idx[lang] = idx

# %%
y = [ lang2idx[lang] for lang in y_cat ]

# %%
training_examples = int(X.shape[0] * 0.8)

X_train = X[:training_examples, :]
y_train = y[:training_examples]

X_val = X[training_examples:, :]
y_val = y[training_examples:]

# %%
# very simple pytorch module, but good enough for task

class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()

        self.fc1 = nn.Linear(input_dim, 50)
        self.fc2 = nn.Linear(50, 6)

    def forward(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
input_dim = X.shape[1]
model = Model(input_dim)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001) 
# NAdam probably not needed due to simplicity

# %%
X_train = torch.Tensor(X_train)
y_train = torch.LongTensor(y_train)

X_val = torch.Tensor(X_val)
y_val = torch.LongTensor(y_val)

# %%
from torch.utils.data import TensorDataset, DataLoader

dataset_tensor = TensorDataset(X_train, y_train)
dataloader = DataLoader(dataset_tensor, batch_size=32, shuffle=True)

# %%
model.train()
# Out:
# Model(
#   (fc1): Linear(in_features=2230, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=6, bias=True)
# )

# %%
for epoch in range(5):
    loss_train = 0

    for X_batch, y_batch in dataloader:
        optimizer.zero_grad()
        
        outputs = model(X_batch)
        loss = loss_fn(outputs, y_batch)
        
        loss.backward()
        optimizer.step()
        
        loss_train += loss.item()
    print(loss_train)
# Out:
# 487.6147324163576
# 39.17166730403005
# 21.963762875254417
# 14.687231717943519
# 8.839342773388944

# %%
Y_val_pred_logits = model(X_val)

# %%
Y_val_pred_proba = torch.softmax(Y_val_pred_logits, dim = 1)

# %%
y_val_pred = torch.argmax(Y_val_pred_proba, dim = 1)

# %%
# Validate data...

print(classification_report(y_val, y_val_pred, target_names=y_symbols))
print('Micro F1:', f1_score(y_val, y_val_pred, average='micro'))
print('Macro F1', f1_score(y_val, y_val_pred, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#          tur       1.00      1.00      1.00     10044
#          eng       1.00      1.00      1.00      9927
#          ita       1.00      1.00      1.00      9990
#          rus       1.00      1.00      1.00      9932
#          epo       1.00      1.00      1.00     10087
#          kab       1.00      1.00      1.00     10020
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000
#
# Micro F1: 0.9985
# Macro F1 0.9985017697777007

# %%
confusion_matrix(y_val, y_val_pred)
# Out:
# array([[10027,     6,     4,     0,     4,     3],
#        [    2,  9912,     3,     0,     6,     4],
#        [    1,     8,  9969,     0,     7,     5],
#        [    0,     0,     1,  9931,     0,     0],
#        [    4,     3,    10,     0, 10067,     3],
#        [    6,     5,     3,     0,     2, 10004]], dtype=int64)
